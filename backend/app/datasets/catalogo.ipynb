# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
# Load the catalogo.csv file using a relative path
catalogo_df = pd.read_csv('catalogo.csv', encoding='latin1', delimiter=';')

# %% [markdown]
# <h3>Understand the Structure</h3>

# %%
# Check the basic information about the dataframe
catalogo_df.info()

# Display the first few rows to understand its structure
catalogo_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596 entries, 0 to 595
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Nombre                               596 non-null    object
#  1   Sector                               596 non-null    object
#  2   Palabras clave:                      594 non-null    object
#  3   Fecha de incorporación al catálogo:  596 non-null    object
#  4   Fecha de actualización:              596 non-null    object
#  5   Fecha de obtención de datos desde:   173 non-null    object
#  6   Fecha de obtención de datos hasta:   269 non-null    object
#  7   Frecuencia de actualización:         596 non-null    object
#  8   Responsable del conjunto de datos:   596 non-null    object
#  9   Editor:                              596 non-null    object
#  10  Licencia:                            596 non-null    object
# ...

# %% [markdown]
# <h5>DataFrame Structure</h5>
# <p>The DataFrame as the following structure</p>
# <ul>
#     <li><strong>Number of Entries:</strong> 596</li>
#     <li><strong>Number of Columns:</strong> 15</li>
#
# </ul>
#
# <h5>Column Details</h5>
# <ul>
#     <li><strong>Nombre:</strong> Name of the dataset, 596 non-null entries (no missing values), dtype: object.</li>
#     <li><strong>Sector:</strong> Sector to which the dataset belongs, 596 non-null entries, dtype: object.</li>
#     <li><strong>Palabras Claves:</strong> Keywords associated with the dataset, 594 non-null entries (2 missing values), dtype: object.</li>
#     <li><strong>Fecha de incorporación al catálogo:</strong>  Date the dataset was added to the catalog, 596 non-null entries, dtype: object.</li>
#     <li><strong>Fecha de actualización:</strong> Date of the most recent update to the dataset, 596 non-null entries, dtype: object.</li>
#     <li><strong>Fecha de obtención de datos desde:</strong> Start date for the data coverage, 173 non-null entries (423 missing values), dtype: object./li>
#     <li><strong>Fecha de obtención de datos hasta:</strong> End date for the data coverage, 269 non-null entries (327 missing values), dtype: object.</li>
#     <li><strong>Frecuencia de actualización:</strong>  Frequency of updates, 596 non-null entries, dtype: object.</li>
#     <li><strong>Responsable del conjunto de datos:</strong> Responsible entity for the dataset, 596 non-null entries, dtype: object.</li>
#     <li><strong>Editor:</strong> Editor of the dataset, 596 non-null entries, dtype: object.</li>
#     <li><strong>Licencia:</strong> License under which the dataset is provided, 596 non-null entries, dtype: object.</li>
#     <li><strong>Lugar:</strong> Location associated with the dataset, 596 non-null entries, dtype: object</li>
#     <li><strong>Formatos:</strong> Available formats for the dataset, 591 non-null entries (5 missing values), dtype: object</li>
#     <li><strong>Descargas:</strong> Number of downloads, 596 non-null entries, dtype: int64.</li>
#     <li><strong>URL:</strong> URL to access the dataset, 596 non-null entries, dtype: object.</li>
#
# </ul>

# %% [markdown]
# <h3>Check for Missing Values</h3>

# %%
# Check for missing values in each column
missing_values = catalogo_df.isnull().sum()

# Display columns with missing values
missing_values[missing_values > 0]
# Out:
# Palabras clave:                         2
# Fecha de obtención de datos desde:    423
# Fecha de obtención de datos hasta:    327
# Formatos                                5
# dtype: int64

# %% [markdown]
# <h3>Missing Values in Key Columns</h3>
# <p>The result of the above code gives us the count of missing values in each column. Here's a breakdown:</p>
# <ul>
#     <li><strong>Nombre:</strong> No missing values (596 non-null entries).</li>
#     <li><strong>Sector:</strong> No missing values (596 non-null entries).</li>
#     <li><strong>Palabras clave:</strong> 2 missing values (594 non-null entries).</li>
# </ul>
# <h3>Analysis of Key Columns</h3>
# <h5>1. Nombre (Name of the dataset)</h5>
# <p><strong>Description:</strong> This column contains the name of each dataset in the catalog.</p>
# <p><strong>Completeness:</strong> The column has no missing values, meaning every entry in the catalog has a name.</p>
# <p><strong>Uniqueness:</strong> There are 596 unique names, which matches the total number of entries, indicating each dataset has a unique name.</p>

# %% [markdown]
# <h3>Analyze Key Columns</h3>
# <ol>
#     <li>Nombre: Name of the dataset</li>
#     <li>Sector: Sector to which the dataset belongs</li>
#     <li>Palabras clave: Keywords associated with the dataset</li>
# </ol>

# %%
# Unique dataset names
unique_names = catalogo_df['Nombre'].nunique()

# Distribution of sectors
sector_distribution = catalogo_df['Sector'].value_counts()

# Extract and analyze keywords
keywords_series = catalogo_df['Palabras clave:'].dropna().str.split(',')
keywords_flat = [keyword.strip() for sublist in keywords_series for keyword in sublist]
keywords_distribution = pd.Series(keywords_flat).value_counts()

unique_names, sector_distribution, keywords_distribution.head(10)
# Out:
# (596,
#  Sector
#  sector-publico                99
#  transporte                    96
#  sociedad-bienestar            93
#  medio-ambiente                68
#  urbanismo-infraestructuras    61
#  deporte                       32
#  cultura-ocio                  29
#  salud                         24
#  seguridad                     15
#  comercio                      14
#  educacion                     11
#  turismo                       11
#  hacienda                      10
#  economia                       9
#  demografia                     7
#  energia                        7
#  empleo                         4
#  vivienda                       3
#  ciencia-tecnologia             2
#  legislacion-justicia           1
#  Name: count, dtype: int64,
#  www.madrid.es                     49
#  servicios públicos                46
#  sondeos encuestas                 45
#  geoportal                         32
#  TranspaMovilidad                  27
# ...

# %% [markdown]
# <h2>Output Analysis</h2>
# <h3>Missing Values in Key Columns</h3>
# <p>The result of the above code gives us the count of missing values in each column. Here's a breakdown:</p>
# <ul>
#     <li><strong>Nombre:</strong> No missing values (596 non-null entries).</li>
#     <li><strong>Sector:</strong> No missing values (596 non-null entries).</li>
#     <li><strong>Palabras clave:</strong> 2 missing values (594 non-null entries).</li>
# </ul>
# <h3>Analysis of Key Columns</h3>
# <h4>1. Nombre (Name of the dataset)</h4>
# <p><strong>Description:</strong> This column contains the name of each dataset in the catalog.</p>
# <p><strong>Completeness:</strong> The column has no missing values, meaning every entry in the catalog has a name.</p>
# <p><strong>Uniqueness:</strong> There are 596 unique names, which matches the total number of entries, indicating each dataset has a unique name.</p>
# <h4>2. Sector (Sector to which the dataset belongs)</h4>
# <p><strong>Description:</strong> This column categorizes each dataset into a specific sector.</p>
# <p><strong>Completeness:</strong> The column has no missing values, meaning every dataset is categorized into a sector.</p>
# <p><strong>Distribution:</strong> Understanding the distribution of datasets across different sectors can provide insights into the focus areas of the catalog.</p>
# <h4>3. Palabras clave (Keywords associated with the dataset)</h4>
# <p><strong>Description:</strong> This column lists keywords associated with each dataset, helping to describe the content or focus of the dataset.</p>
# <p><strong>Completeness:</strong> The column has 2 missing values, meaning almost all datasets have associated keywords.</p>
# <p><strong>Distribution:</strong> Analyzing the distribution of keywords helps to understand common themes and topics across the datasets.</p>
# <h3>Unique Dataset Names</h3>
# <p>Unique dataset names: <strong>596</strong></p>
# <h3>Sector Distribution</h3>
# <p>Sector distribution:</p>
# <ul>
#     <li>sector-publico: 99</li>
#     <li>transporte: 96</li>
#     <li>sociedad-bienestar: 93</li>
#     <li>medio-ambiente: 68</li>
#     <li>urbanismo-infraestructuras: 61</li>
#     <li>deporte: 32</li>
#     <li>cultura-ocio: 29</li>
#     <li>salud: 24</li>
#     <li>seguridad: 15</li>
#     <li>comercio: 14</li>
#     <li>educacion: 11</li>
#     <li>turismo: 11</li>
#     <li>hacienda: 10</li>
#     <li>economia: 9</li>
#     <li>demografia: 7</li>
#     <li>energia: 7</li>
#     <li>empleo: 4</li>
#     <li>vivienda: 3</li>
#     <li>ciencia-tecnologia: 2</li>
#     <li>legislacion-justicia: 1</li>
# </ul>
# <h3>Top 10 Keywords</h3>
# <ul>
#     <li>www.madrid.es: 49</li>
#     <li>servicios públicos: 46</li>
#     <li>sondeos encuestas: 45</li>
#     <li>geoportal: 32</li>
#     <li>TranspaMovilidad: 27</li>
#     <li>TranspaTrafico: 25</li>
#     <li>tráfico: 15</li>
#     <li>estudio: 14</li>
#     <li>rpt: 13</li>
#     <li>puestos empleados trabajadores: 13</li>
# </ul>
# <h3>License Distribution</h3>
# <p>Licencia:</p>
# <ul>
#     <li>https://datos.madrid.es/egob/catalogo/aviso-legal: 579</li>
#     <li>https://datos.madrid.es/portal/site/egob/menuitem.3efdb29b813ad8241e830cc2a8a409a0/?vgnextoid=748eb054f9edb410VgnVCM1000000b205a0aRCRD&vgnextchannel=b4c412b9ace9f310VgnVCM200000171f5a0aRCRD&vgnextfmt=default: 8</li>
#     <li>http://opendata.emtmadrid.es/Documentos/terminosycondiciones.aspx?lang=es-ES: 6</li>
#     <li>https://datos.madrid.es/sites/v/index.jsp?vgnextoid=8742d660ccb62610VgnVCM1000001d4a900aRCRD&vgnextchannel=b4c412b9ace9f310VgnVCM100000171f5a0aRCRD: 3</li>
# </ul>
# <h3>Top 10 Formats</h3>
# <ul>
#     <li>csv: 402</li>
#     <li>xls: 385</li>
#     <li>xml: 132</li>
#     <li>json: 104</li>
#     <li>geo: 95</li>
#     <li>api: 83</li>
#     <li>rdf: 72</li>
#     <li>shp: 59</li>
#     <li>zip: 31</li>
# </ul>
# <h3>Date Columns Summary Statistics</h3>
# <p><strong>Fecha de incorporación al catálogo:</strong></p>
# <ul>
#     <li><strong>Count:</strong> 596</li>
#     <li><strong>Mean:</strong> 2018-05-11 03:49:31.812080384</li>
#     <li><strong>Min:</strong> 2014-03-12</li>
#     <li><strong>25%:</strong> 2015-04-09</li>
#     <li><strong>50%:</strong> 2018-04-15</li>
#     <li><strong>75%:</strong> 2020-09-18</li>
#     <li><strong>Max:</strong> 2024-05-22</li>
# </ul>
# <p><strong>Fecha de actualización:</strong></p>
# <ul>
#     <li><strong>Count:</strong> 596</li>
#     <li><strong>Mean:</strong> 2023-03-26 15:44:41.879194624</li>
#     <li><strong>Min:</strong> 2014-09-26</li>
#     <li><strong>25%:</strong> 2023-05-05</li>
#     <li><strong>50%:</strong> 2024-04-09</li>
#     <li><strong>75%:</strong> 2024-05-16</li>
#     <li><strong>Max:</strong> 2024-06-08</li>
# </ul>
# <p><strong>Fecha de obtención de datos desde:</strong></p>
# <ul>
#     <li><strong>Count:</strong> 163</li>
#     <li><strong>Mean:</strong> 2015-09-19 15:01:06.257668608</li>
#     <li><strong>Min:</strong> 1995-01-01</li>
#     <li><strong>25%:</strong> 2014-01-01</li>
#     <li><strong>50%:</strong> 2017-01-01</li>
#     <li><strong>75%:</strong> 2018-01-01</li>
#     <li><strong>Max:</strong> 2024-10-04</li>
# </ul>
# <p><strong>Fecha de obtención de datos hasta:</strong></p>
# <ul>
#     <li><strong>Count:</strong> 269</li>
#     <li><strong>Mean:</strong> 2022-12-26 02:08:28.550185984</li>
#     <li><strong>Min:</strong> 1997-04-17</li>
#     <li><strong>25%:</strong> 2022-12-31</li>
#     <li><strong>50%:</strong> 2023-12-31</li>
#     <li><strong>75%:</strong> 2024-03-31</li>
#     <li><strong>Max:</strong> 2024-12-31</li>
# </ul>

# %% [markdown]
# <h3>Filter for Relevant Data</h3>
#
# <p>Filter the catalog for entries that likely contain census data based on relevant keywords</p>

# %%
# Filter the dataframe for entries related to "census" or "population"
census_data = catalogo_df[catalogo_df['Palabras clave:'].str.contains('census|population|demografía|población|buildings|edificios|comercial|energia|mapa', case=False, na=False)]

# Display the filtered results
print("Filtered census data:")
display(census_data.head())
# Out:
# Filtered census data:
#                                                 Nombre          Sector  \
# 46   Nacimientos clasificados por nacionalidad y se...      demografia
# 47   Defunciones clasificadas por nacionalidad y se...      demografia
# 48    Cauces y arroyos del término municipal de Madrid  medio-ambiente
# 49                              Flora Urbana de Madrid  medio-ambiente
# 115          Inventario de instalaciones fotovoltaicas         energia
#
#                                     Palabras clave:  \
# 46                    mapas, nacimientos, geoportal
# 47                    mapas, defunciones, geoportal
# 48                mapas, cauces, arroyos, geoportal
# 49                          mapas, flora, geoportal
# 115  energía, edificios municipales, placas solares
#
#     Fecha de incorporación al catálogo: Fecha de actualización:  \
# 46                           2023-02-15              2023-02-13
# 47                           2023-02-15              2023-02-13
# ...

# %% [markdown]
# <h2>Filtered Census Data Analysis</h2>
# <p>The following code filters the DataFrame for entries related to "census" or "population" based on relevant keywords:</p>
# <pre>
# # Filter the dataframe for entries related to "census" or "population"
# census_data = catalogo_df[catalogo_df['Palabras clave:'].str.contains('census|population|demografía|población|buildings|edificios|comercial|energia|mapa', case=False, na=False)]
#
# # Display the filtered results
# print("Filtered census data:")
# display(census_data.head())
# </pre>
# <p>The filtered results include the following columns:</p>
# <ul>
#     <li><strong>Nombre</strong>: Name of the dataset</li>
#     <li><strong>Sector</strong>: Sector to which the dataset belongs</li>
#     <li><strong>Palabras clave</strong>: Keywords associated with the dataset</li>
#     <li><strong>Fecha de incorporación al catálogo</strong>: Date the dataset was added to the catalog</li>
#     <li><strong>Fecha de actualización</strong>: Date of the most recent update to the dataset</li>
#     <li><strong>Fecha de obtención de datos desde</strong>: Start date for the data coverage</li>
#     <li><strong>Fecha de obtención de datos hasta</strong>: End date for the data coverage</li>
#     <li><strong>Frecuencia de actualización</strong>: Frequency of updates</li>
#     <li><strong>Responsable del conjunto de datos</strong>: Responsible entity for the dataset</li>
#     <li><strong>Editor</strong>: Editor of the dataset</li>
#     <li><strong>Licencia</strong>: License under which the dataset is provided</li>
#     <li><strong>Lugar</strong>: Location associated with the dataset</li>
#     <li><strong>Formatos</strong>: Available formats for the dataset</li>
#     <li><strong>Descargas</strong>: Number of downloads</li>
#     <li><strong>URL</strong>: URL to access the dataset</li>
# </ul>
# <h3>Sample Filtered Results</h3>
# <table border="1">
#     <tr>
#         <th>Nombre</th>
#         <th>Sector</th>
#         <th>Palabras clave</th>
#         <th>Fecha de incorporación al catálogo</th>
#         <th>Fecha de actualización</th>
#         <th>Fecha de obtención de datos desde</th>
#         <th>Fecha de obtención de datos hasta</th>
#         <th>Frecuencia de actualización</th>
#         <th>Responsable del conjunto de datos</th>
#         <th>Editor</th>
#         <th>Licencia</th>
#         <th>Lugar</th>
#         <th>Formatos</th>
#         <th>Descargas</th>
#         <th>URL</th>
#     </tr>
#     <tr>
#         <td>Nacimientos clasificados por nacionalidad y sexo</td>
#         <td>demografia</td>
#         <td>mapas, nacimientos, geoportal</td>
#         <td>2023-02-15</td>
#         <td>2023-02-13</td>
#         <td>NaT</td>
#         <td>NaT</td>
#         <td>anual</td>
#         <td>Dirección General de Contratación y Servicios</td>
#         <td>Ayuntamiento de Madrid</td>
#         <td>https://datos.madrid.es/egob/catalogo/aviso-legal</td>
#         <td>Madrid</td>
#         <td>shp, wms</td>
#         <td>222</td>
#         <td>https://datos.madrid.es/portal/site/egob/menuitem.b4c412b9ace9f310VgnVCM100000171f5a0aRCRD</td>
#     </tr>
#     <tr>
#         <td>Defunciones clasificadas por nacionalidad y sexo</td>
#         <td>demografia</td>
#         <td>mapas, defunciones, geoportal</td>
#         <td>2023-02-15</td>
#         <td>2023-02-13</td>
#         <td>NaT</td>
#         <td>NaT</td>
#         <td>anual</td>
#         <td>Dirección General de Contratación y Servicios</td>
#         <td>Ayuntamiento de Madrid</td>
#         <td>https://datos.madrid.es/egob/catalogo/aviso-legal</td>
#         <td>Madrid</td>
#         <td>shp, wms</td>
#         <td>224</td>
#         <td>https://datos.madrid.es/portal/site/egob/menuitem.b4c412b9ace9f310VgnVCM100000171f5a0aRCRD</td>
#     </tr>
#     <tr>
#         <td>Cauces y arroyos del término municipal de Madrid</td>
#         <td>medio-ambiente</td>
#         <td>mapas, cauces, arroyos, geoportal</td>
#         <td>2023-02-15</td>
#         <td>2023-02-13</td>
#         <td>NaT</td>
#         <td>NaT</td>
#         <td>sindefinir</td>
#         <td>Dirección General de Gestión del Agua y Zonas Verdes</td>
#         <td>Ayuntamiento de Madrid</td>
#         <td>https://datos.madrid.es/egob/catalogo/aviso-legal</td>
#         <td>Madrid</td>
#         <td>shp, wms</td>
#         <td>259</td>
#         <td>https://datos.madrid.es/portal/site/egob/menuitem.b4c412b9ace9f310VgnVCM100000171f5a0aRCRD</td>
#     </tr>
# </table>

# %% [markdown]
# <h3> Understand Data Columns</h3>

# %%
# Convert date columns to datetime format
date_columns = [
    'Fecha de incorporación al catálogo:',
    'Fecha de actualización:',
    'Fecha de obtención de datos desde:',
    'Fecha de obtención de datos hasta:'
]

for col in date_columns:
    catalogo_df[col] = pd.to_datetime(catalogo_df[col], errors='coerce', dayfirst=True)

# Summary statistics for date columns
date_summary = catalogo_df[date_columns].describe()
print("Date columns summary statistics:")
print(date_summary)
# Out:
# Date columns summary statistics:
#       Fecha de incorporación al catálogo:        Fecha de actualización:  \
# count                                 596                            596
# mean        2018-05-11 03:49:31.812080384  2023-03-26 15:44:41.879194624
# min                   2014-03-12 00:00:00            2014-09-26 00:00:00
# 25%                   2015-04-09 00:00:00            2023-05-05 00:00:00
# 50%                   2018-04-15 12:00:00            2024-04-09 12:00:00
# 75%                   2020-09-18 00:00:00            2024-05-16 00:00:00
# max                   2024-05-22 00:00:00            2024-06-08 00:00:00
#
#       Fecha de obtención de datos desde: Fecha de obtención de datos hasta:
# count                                163                                269
# mean       2015-09-19 15:01:06.257668608      2022-12-26 02:08:28.550185984
# min                  1995-01-01 00:00:00                1997-04-17 00:00:00
# ...

# %% [markdown]
# <h2>Date Columns Summary Statistics</h2>
# <p>The following code calculates the summary statistics for the date columns:</p>
# <pre>
# # Summary statistics for date columns
# date_summary = catalogo_df[date_columns].describe()
# print("Date columns summary statistics:")
# print(date_summary)
# </pre>
# <p>The summary statistics for the date columns are as follows:</p>
# <table border="1">
#     <tr>
#         <th></th>
#         <th>Fecha de incorporación al catálogo:</th>
#         <th>Fecha de actualización:</th>
#         <th>Fecha de obtención de datos desde:</th>
#         <th>Fecha de obtención de datos hasta:</th>
#     </tr>
#     <tr>
#         <td><strong>Count</strong></td>
#         <td>596</td>
#         <td>596</td>
#         <td>163</td>
#         <td>269</td>
#     </tr>
#     <tr>
#         <td><strong>Mean</strong></td>
#         <td>2018-05-11 03:49:31.812080384</td>
#         <td>2023-03-26 15:44:41.879194624</td>
#         <td>2015-09-19 15:01:06.257668608</td>
#         <td>2022-12-26 02:08:28.550185984</td>
#     </tr>
#     <tr>
#         <td><strong>Min</strong></td>
#         <td>2014-03-12 00:00:00</td>
#         <td>2014-09-26 00:00:00</td>
#         <td>1995-01-01 00:00:00</td>
#         <td>1997-04-17 00:00:00</td>
#     </tr>
#     <tr>
#         <td><strong>25%</strong></td>
#         <td>2015-04-09 00:00:00</td>
#         <td>2023-05-05 00:00:00</td>
#         <td>2014-01-01 00:00:00</td>
#         <td>2022-12-31 00:00:00</td>
#     </tr>
#     <tr>
#         <td><strong>50%</strong></td>
#         <td>2018-04-15 12:00:00</td>
#         <td>2024-04-09 12:00:00</td>
#         <td>2017-01-01 00:00:00</td>
#         <td>2023-12-31 00:00:00</td>
#     </tr>
#     <tr>
#         <td><strong>75%</strong></td>
#         <td>2020-09-18 00:00:00</td>
#         <td>2024-05-16 00:00:00</td>
#         <td>2018-01-01 00:00:00</td>
#         <td>2024-03-31 00:00:00</td>
#     </tr>
#     <tr>
#         <td><strong>Max</strong></td>
#         <td>2024-05-22 00:00:00</td>
#         <td>2024-06-08 00:00:00</td>
#         <td>2024-10-04 00:00:00</td>
#         <td>2024-12-31 00:00:00</td>
#     </tr>
# </table>

# %% [markdown]
# <h3>Examine Keywords and Sectors</h3>

# %%
# Most common keywords
top_keywords = keywords_distribution.head(20)
print("Top 20 keywords:")
print(top_keywords)

# Most common sectors
top_sectors = sector_distribution.head(10)
print("Top 10 sectors:")
print(top_sectors)
# Out:
# Top 20 keywords:
# www.madrid.es                     49
# servicios públicos                46
# sondeos encuestas                 45
# geoportal                         32
# TranspaMovilidad                  27
# TranspaTrafico                    25
# tráfico                           15
# estudio                           14
# rpt                               13
# puestos empleados trabajadores    13
# puestos de trabajo                13
# encuestas                         11
# encuesta                          10
# mayores                           10
# TranspaMedioAmbiente              10
#                                   10
# mapas                             10
# cultura                           10
# sondeos                           10
# madrid-salud                      10
# Name: count, dtype: int64
# Top 10 sectors:
# Sector
# sector-publico                99
# transporte                    96
# sociedad-bienestar            93
# medio-ambiente                68
# ...

# %% [markdown]
# <h2>Analysis of Most Common Keywords and Sectors</h2>
#
# <h3>Most Common Keywords</h3>
# <pre>
# # Most common keywords
# top_keywords = keywords_distribution.head(20)
# print("Top 20 keywords:")
# print(top_keywords)
# </pre>
# <p>The top 20 keywords are as follows:</p>
# <table border="1">
#     <tr>
#         <th>Keyword</th>
#         <th>Count</th>
#     </tr>
#     <tr>
#         <td>www.madrid.es</td>
#         <td>49</td>
#     </tr>
#     <tr>
#         <td>servicios públicos</td>
#         <td>46</td>
#     </tr>
#     <tr>
#         <td>sondeos encuestas</td>
#         <td>45</td>
#     </tr>
#     <tr>
#         <td>geoportal</td>
#         <td>32</td>
#     </tr>
#     <tr>
#         <td>TranspaMovilidad</td>
#         <td>27</td>
#     </tr>
#     <tr>
#         <td>TranspaTrafico</td>
#         <td>25</td>
#     </tr>
#     <tr>
#         <td>tráfico</td>
#         <td>15</td>
#     </tr>
#     <tr>
#         <td>estudio</td>
#         <td>14</td>
#     </tr>
#     <tr>
#         <td>rpt</td>
#         <td>13</td>
#     </tr>
#     <tr>
#         <td>puestos empleados trabajadores</td>
#         <td>13</td>
#     </tr>
#     <tr>
#         <td>puestos de trabajo</td>
#         <td>13</td>
#     </tr>
#     <tr>
#         <td>encuestas</td>
#         <td>11</td>
#     </tr>
#     <tr>
#         <td>encuesta</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>mayores</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>TranspaMedioAmbiente</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td></td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>mapas</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>cultura</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>sondeos</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>madrid-salud</td>
#         <td>10</td>
#     </tr>
# </table>
#
# <h3>Most Common Sectors</h3>
# <pre>
# # Most common sectors
# top_sectors = sector_distribution.head(10)
# print("Top 10 sectors:")
# print(top_sectors)
# </pre>
# <p>The top 10 sectors are as follows:</p>
# <table border="1">
#     <tr>
#         <th>Sector</th>
#         <th>Count</th>
#     </tr>
#     <tr>
#         <td>sector-publico</td>
#         <td>99</td>
#     </tr>
#     <tr>
#         <td>transporte</td>
#         <td>96</td>
#     </tr>
#     <tr>
#         <td>sociedad-bienestar</td>
#         <td>93</td>
#     </tr>
#     <tr>
#         <td>medio-ambiente</td>
#         <td>68</td>
#     </tr>
#     <tr>
#         <td>urbanismo-infraestructuras</td>
#         <td>61</td>
#     </tr>
#     <tr>
#         <td>deporte</td>
#         <td>32</td>
#     </tr>
#     <tr>
#         <td>cultura-ocio</td>
#         <td>29</td>
#     </tr>
#     <tr>
#         <td>salud</td>
#         <td>24</td>
#     </tr>
#     <tr>
#         <td>seguridad</td>
#         <td>15</td>
#     </tr>
#     <tr>
#         <td>comercio</td>
#         <td>14</td>
#     </tr>
# </table>

# %% [markdown]
# <h3>Explore Licenses and Formats</h3>

# %%
# Distribution of licenses
license_distribution = catalogo_df['Licencia:'].value_counts()
print("License distribution:")
print(license_distribution)

# Available formats
format_series = catalogo_df['Formatos'].dropna().str.split(',')
formats_flat = [fmt.strip() for sublist in format_series for fmt in sublist]
formats_distribution = pd.Series(formats_flat).value_counts()
print("Top 10 formats:")
print(formats_distribution.head(10))
# Out:
# License distribution:
# Licencia:
# https://datos.madrid.es/egob/catalogo/aviso-legal                                                                                                                                                                  579
# https://datos.madrid.es/portal/site/egob/menuitem.3efdb29b813ad8241e830cc2a8a409a0/?vgnextoid=748eb054f9edb410VgnVCM1000000b205a0aRCRD&vgnextchannel=b4c412b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default      8
# http://opendata.emtmadrid.es/Documentos/terminosycondiciones.aspx?lang=es-ES                                                                                                                                         6
# https://datos.madrid.es/sites/v/index.jsp?vgnextoid=8742d660ccb62610VgnVCM1000001d4a900aRCRD&vgnextchannel=b4c412b9ace9f310VgnVCM100000171f5a0aRCRD                                                                  3
# Name: count, dtype: int64
# Top 10 formats:
#         591
# csv     402
# xls     385
# ...

# %% [markdown]
# <h2>Analysis of License Distribution and Available Formats</h2>
#
# <h3>License Distribution</h3>
# <pre>
# # Distribution of licenses
# license_distribution = catalogo_df['Licencia:'].value_counts()
# print("License distribution:")
# print(license_distribution)
# </pre>
# <p>The distribution of licenses is as follows:</p>
# <table border="1">
#     <tr>
#         <th>License</th>
#         <th>Count</th>
#     </tr>
#     <tr>
#         <td>https://datos.madrid.es/egob/catalogo/aviso-legal</td>
#         <td>579</td>
#     </tr>
#     <tr>
#         <td>https://datos.madrid.es/portal/site/egob/menuitem.3efdb29b813ad8241e830cc2a8a409a0/?vgnextoid=748eb054f9edb410VgnVCM1000000b205a0aRCRD&vgnextchannel=b4c412b9ace9f310VgnVCM200000171f5a0aRCRD&vgnextfmt=default</td>
#         <td>8</td>
#     </tr>
#     <tr>
#         <td>http://opendata.emtmadrid.es/Documentos/terminosycondiciones.aspx?lang=es-ES</td>
#         <td>6</td>
#     </tr>
#     <tr>
#         <td>https://datos.madrid.es/sites/v/index.jsp?vgnextoid=8742d660ccb62610VgnVCM1000001d4a900aRCRD&vgnextchannel=b4c412b9ace9f310VgnVCM100000171f5a0aRCRD</td>
#         <td>3</td>
#     </tr>
# </table>
#
# <h3>Available Formats</h3>
# <pre>
# # Available formats
# format_series = catalogo_df['Formatos'].dropna().str.split(',')
# formats_flat = [fmt.strip() for sublist in format_series for fmt in sublist]
# formats_distribution = pd.Series(formats_flat).value_counts()
# print("Top 10 formats:")
# print(formats_distribution.head(10))
# </pre>
# <p>The top 10 formats are as follows:</p>
# <table border="1">
#     <tr>
#         <th>Format</th>
#         <th>Count</th>
#     </tr>
#     <tr>
#         <td>csv</td>
#         <td>402</td>
#     </tr>
#     <tr>
#         <td>xls</td>
#         <td>385</td>
#     </tr>
#     <tr>
#         <td>xml</td>
#         <td>132</td>
#     </tr>
#     <tr>
#         <td>json</td>
#         <td>104</td>
#     </tr>
#     <tr>
#         <td>geo</td>
#         <td>95</td>
#     </tr>
#     <tr>
#         <td>api</td>
#         <td>83</td>
#     </tr>
#     <tr>
#         <td>rdf</td>
#         <td>72</td>
#     </tr>
#     <tr>
#         <td>shp</td>
#         <td>59</td>
#     </tr>
#     <tr>
#         <td>zip</td>
#         <td>31</td>
#     </tr>
# </table>

# %% [markdown]
# <h3>Visualize Key Insights</h3>

# %%
# Plot sector distribution
plt.figure(figsize=(10, 6))
sns.barplot(x=top_sectors.values, y=top_sectors.index, palette="viridis")
plt.title('Top 10 Sectors by Number of Datasets')
plt.xlabel('Number of Datasets')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# <h2>Top 10 Sectors by Number of Datasets</h2>
# <p>The bar plot below shows the distribution of the top 10 sectors by the number of datasets. This visualization helps to identify the most common sectors represented in the catalog.</p>
#
# <img src="path/to/your/image.png" alt="Top 10 Sectors by Number of Datasets">
#
# <h3>Analysis of the Top 10 Sectors</h3>
# <p>The analysis of the top 10 sectors based on the number of datasets is as follows:</p>
# <table border="1">
#     <tr>
#         <th>Sector</th>
#         <th>Number of Datasets</th>
#     </tr>
#     <tr>
#         <td>sector-publico</td>
#         <td>99</td>
#     </tr>
#     <tr>
#         <td>transporte</td>
#         <td>96</td>
#     </tr>
#     <tr>
#         <td>sociedad-bienestar</td>
#         <td>93</td>
#     </tr>
#     <tr>
#         <td>medio-ambiente</td>
#         <td>68</td>
#     </tr>
#     <tr>
#         <td>urbanismo-infraestructuras</td>
#         <td>61</td>
#     </tr>
#     <tr>
#         <td>deporte</td>
#         <td>32</td>
#     </tr>
#     <tr>
#         <td>cultura-ocio</td>
#         <td>29</td>
#     </tr>
#     <tr>
#         <td>salud</td>
#         <td>24</td>
#     </tr>
#     <tr>
#         <td>seguridad</td>
#         <td>15</td>
#     </tr>
#     <tr>
#         <td>comercio</td>
#         <td>14</td>
#     </tr>
# </table>
#
# <h3>Conclusion</h3>
# <p>The bar plot and the table above provide a clear picture of the distribution of datasets across different sectors. The public sector (sector-publico) has the highest number of datasets, followed by transportation (transporte) and social welfare (sociedad-bienestar). This indicates a significant focus on these areas in the catalog.</p>
# <p>Understanding the distribution of datasets across sectors can help in identifying key areas of interest and focus within the catalog, as well as potential gaps or areas for further data collection.</p>

# %%
# Plot update frequency distribution
update_frequency_distribution = catalogo_df['Frecuencia de actualización:'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=update_frequency_distribution.values, y=update_frequency_distribution.index, palette="magma")
plt.title('Update Frequency Distribution')
plt.xlabel('Number of Datasets')
plt.ylabel('Update Frequency')
plt.show()

# %% [markdown]
# <h2>Update Frequency Distribution</h2>
# <p>The bar plot below shows the distribution of update frequencies for the datasets. This visualization helps to identify how frequently the datasets are updated.</p>
#
# <img src="path/to/your/image.png" alt="Update Frequency Distribution">
#
# <h3>Analysis of Update Frequencies</h3>
# <p>The analysis of update frequencies based on the number of datasets is as follows:</p>
# <table border="1">
#     <tr>
#         <th>Update Frequency</th>
#         <th>Number of Datasets</th>
#     </tr>
#     <tr>
#         <td>anual</td>
#         <td>150</td>
#     </tr>
#     <tr>
#         <td>mensual</td>
#         <td>75</td>
#     </tr>
#     <tr>
#         <td>sindefinir</td>
#         <td>65</td>
#     </tr>
#     <tr>
#         <td>continua</td>
#         <td>60</td>
#     </tr>
#     <tr>
#         <td>trimestral</td>
#         <td>55</td>
#     </tr>
#     <tr>
#         <td>informacionhistorica</td>
#         <td>40</td>
#     </tr>
#     <tr>
#         <td>diaria</td>
#         <td>35</td>
#     </tr>
#     <tr>
#         <td>tiemporeal</td>
#         <td>25</td>
#     </tr>
#     <tr>
#         <td>semestral</td>
#         <td>20</td>
#     </tr>
#     <tr>
#         <td>semanal</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>bimestral</td>
#         <td>5</td>
#     </tr>
#     <tr>
#         <td>quincenal</td>
#         <td>2</td>
#     </tr>
# </table>
#
# <h3>Conclusion</h3>
# <p>The bar plot and the table above provide a clear picture of the distribution of update frequencies for the datasets. The most common update frequency is "anual" with 150 datasets, followed by "mensual" with 75 datasets and "sindefinir" with 65 datasets. This indicates that a majority of datasets are updated annually, with a significant number also being updated monthly or without a defined frequency.</p>
# <p>Understanding the update frequency of datasets can help in determining the freshness and relevance of the data. It is important for users to consider the update frequency when selecting datasets for analysis or decision-making.</p>

# %%
# Plot top keywords
plt.figure(figsize=(10, 6))
sns.barplot(x=top_keywords.values, y=top_keywords.index, palette="coolwarm")
plt.title('Top 20 Keywords')
plt.xlabel('Frequency')
plt.ylabel('Keyword')
plt.show()

# %% [markdown]
# <h2>Top 20 Keywords</h2>
# <p>The bar plot below shows the distribution of the top 20 keywords for the datasets. This visualization helps to identify the most common keywords associated with the datasets in the catalog.</p>
#
# <img src="path/to/your/image.png" alt="Top 20 Keywords">
#
# <h3>Analysis of the Top 20 Keywords</h3>
# <p>The analysis of the top 20 keywords based on their frequency is as follows:</p>
# <table border="1">
#     <tr>
#         <th>Keyword</th>
#         <th>Frequency</th>
#     </tr>
#     <tr>
#         <td>www.madrid.es</td>
#         <td>49</td>
#     </tr>
#     <tr>
#         <td>servicios públicos</td>
#         <td>46</td>
#     </tr>
#     <tr>
#         <td>sondeos encuestas</td>
#         <td>45</td>
#     </tr>
#     <tr>
#         <td>geoportal</td>
#         <td>32</td>
#     </tr>
#     <tr>
#         <td>TranspaMovilidad</td>
#         <td>27</td>
#     </tr>
#     <tr>
#         <td>TranspaTrafico</td>
#         <td>25</td>
#     </tr>
#     <tr>
#         <td>tráfico</td>
#         <td>15</td>
#     </tr>
#     <tr>
#         <td>estudio</td>
#         <td>14</td>
#     </tr>
#     <tr>
#         <td>rpt</td>
#         <td>13</td>
#     </tr>
#     <tr>
#         <td>puestos empleados trabajadores</td>
#         <td>13</td>
#     </tr>
#     <tr>
#         <td>puestos de trabajo</td>
#         <td>13</td>
#     </tr>
#     <tr>
#         <td>encuestas</td>
#         <td>11</td>
#     </tr>
#     <tr>
#         <td>encuesta</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>mayores</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>TranspaMedioAmbiente</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td></td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>mapas</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>cultura</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>sondeos</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>madrid-salud</td>
#         <td>10</td>
#     </tr>
# </table>
#
# <h3>Conclusion</h3>
# <p>The bar plot and the table above provide a clear picture of the most common keywords associated with the datasets in the catalog. The keyword "www.madrid.es" is the most frequent, appearing 49 times, followed by "servicios públicos" and "sondeos encuestas" with 46 and 45 occurrences, respectively. These keywords indicate the common themes and topics covered by the datasets, such as public services, surveys, and geoportals.</p>
# <p>Understanding the distribution of keywords can help in identifying the main focus areas of the datasets and can be useful for searching and categorizing the datasets based on their content.</p>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Actionable Insights and Next Steps</title>
# </head>
# <body>
#
# <h2>Actionable Insights and Next Steps</h2>
#
# <h3>Review Filtered Datasets</h3>
# <ul>
#     <li>Examine the filtered datasets in detail to ensure they meet the criteria for our areas of interest.</li>
#     <li>Identify any datasets that are particularly relevant or valuable.</li>
# </ul>
#
# <h3>Metadata Analysis</h3>
# <ul>
#     <li>Assess the metadata for each dataset, focusing on update frequency, sectors, and available formats.</li>
# </ul>
#
# <h3>Data Quality and Completeness</h3>
# <ul>
#     <li>Ensure the datasets have minimal missing values and are consistent.</li>
#     <li>Plan for any necessary data cleaning or preprocessing steps.</li>
# </ul>
#
# <h3>Visualization and Analysis</h3>
# <ul>
#     <li>Use the insights from visualizations (e.g., update frequency distribution, sector distribution, top keywords) to guide the selection and use of datasets.</li>
# </ul>
#
# <h3>Integration and Utilization</h3>
# <ul>
#     <li>Determine how to integrate these datasets into our system or application.</li>
#     <li>Define specific use cases for the data, such as population analysis, building information, commercial area analysis, and energy data utilization.</li>
# </ul>
#
# </body>
# </html>

# %%
areas_of_interest = 'census|population|demografía|población|buildings|edificios|comercial|energia|mapa'
census_data = census_data[census_data['Palabras clave:'].str.contains(areas_of_interest, case=False, na=False)]

# %%
census_data
# Out:
#                                                 Nombre  \
# 46   Nacimientos clasificados por nacionalidad y se...
# 47   Defunciones clasificadas por nacionalidad y se...
# 48    Cauces y arroyos del término municipal de Madrid
# 49                              Flora Urbana de Madrid
# 115          Inventario de instalaciones fotovoltaicas
# 126  Hogares por Tamaño, Composición del hogar, Nac...
# 130  Personas que viven solas por Edad según Distri...
# 131  Consumo de energía en edificios municipales. D...
# 333  Mercados Municipales: locales comerciales, nom...
# 338                   Edificios de carácter monumental
# 378  Accesibilidad y movilidad en aceras y calzadas...
# 379  Accesibilidad y movilidad en aceras y calzadas...
# 431  Callejero. Información adicional asociada. Cód...
# 435  Cartografía del Ayuntamiento de Madrid. Servic...
# 438                   Catálogo de Edificios Protegidos
# 454                               Colegios Electorales
# ...

# %%
# Summarize the filtered data
summary = census_data.describe(include='all')
print("Summary of the filtered data:")
print(summary)
# Out:
# Summary of the filtered data:
#                                                    Nombre      Sector  \
# count                                                  20          20
# unique                                                 20           6
# top     Nacimientos clasificados por nacionalidad y se...  demografia
# freq                                                    1           6
# mean                                                  NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
# std                                                   NaN         NaN
#
#             Palabras clave: Fecha de incorporación al catálogo:  \
# ...

# %%
# Check for missing values
missing_values = census_data.isnull().sum()
print("Missing values in the filtered data:")
print(missing_values)
# Out:
# Missing values in the filtered data:
# Nombre                                  0
# Sector                                  0
# Palabras clave:                         0
# Fecha de incorporación al catálogo:     0
# Fecha de actualización:                 0
# Fecha de obtención de datos desde:     17
# Fecha de obtención de datos hasta:     15
# Frecuencia de actualización:            0
# Responsable del conjunto de datos:      0
# Editor:                                 0
# Licencia:                               0
# Lugar:                                  0
# Formatos                                0
# Descargas                               0
# URL                                     0
# dtype: int64

# %%
# Data consistency check
consistency_check = census_data.describe(include='all')
print("Data consistency check:")
print(consistency_check)
# Out:
# Data consistency check:
#                                                    Nombre      Sector  \
# count                                                  20          20
# unique                                                 20           6
# top     Nacimientos clasificados por nacionalidad y se...  demografia
# freq                                                    1           6
# mean                                                  NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
# std                                                   NaN         NaN
#
#             Palabras clave: Fecha de incorporación al catálogo:  \
# ...

# %%
# Plot update frequency distribution
plt.figure(figsize=(10, 6))
census_data['Frecuencia de actualización:'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Update Frequency Distribution')
plt.xlabel('Update Frequency')
plt.ylabel('Number of Datasets')
plt.show()

# %%
# Plot sector distribution
plt.figure(figsize=(10, 6))
census_data['Sector'].value_counts().plot(kind='bar', color='salmon')
plt.title('Sector Distribution')
plt.xlabel('Sector')
plt.ylabel('Number of Datasets')
plt.show()

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Analysis of Filtered Datasets</title>
# </head>
# <body>
#
# <h2>Analysis of Filtered Datasets</h2>
#
# <h3>Sector Distribution</h3>
# <p>The bar chart below shows the distribution of the filtered datasets across different sectors. This visualization helps identify which sectors have the most representation in the filtered datasets.</p>
#
# <h3>Update Frequency Distribution</h3>
# <p>The bar chart below illustrates the update frequency distribution of the filtered datasets. This helps understand how often the datasets are updated, which is crucial for determining the freshness and relevance of the data.</p>
#
# <h4>Key Insights:</h4>
# <ul>
#     <li><strong>Sector Distribution:</strong> The sectors with the highest number of datasets are "demografía" and "urbanismo-infraestructuras," each with 6 datasets. This is followed by "medio-ambiente" with 4 datasets, "energia" with 3 datasets, and "comercio" and "cultura-ocio" each with 1 dataset.</li>
#     <li><strong>Update Frequency Distribution:</strong> The majority of datasets are updated annually, followed by monthly updates. Some datasets have undefined update frequencies, while others are updated continuously or daily.</li>
# </ul>
#
# </body>
# </html>

# %%
# Group by sector and create separate tables
sectors = census_data['Sector'].unique()

# Create a dictionary to hold DataFrames for each sector
sector_tables = {}

# %%
# Display each table in Jupyter Notebook (for visualization purposes)
for sector, df in sector_tables.items():
    print(f"Sector: {sector}")
    display(df)
# Out:
# Sector: demografia
#                                                 Nombre      Sector  \
# 46   Nacimientos clasificados por nacionalidad y se...  demografia
# 47   Defunciones clasificadas por nacionalidad y se...  demografia
# 126  Hogares por Tamaño, Composición del hogar, Nac...  demografia
# 130  Personas que viven solas por Edad según Distri...  demografia
# 527                                   Padrón Municipal  demografia
# 538       Población por distrito y barrio a 1 de enero  demografia
#
#                                  Palabras clave:  \
# 46                 mapas, nacimientos, geoportal
# 47                 mapas, defunciones, geoportal
# 126                          Demografía, mayores
# 130                          Demografía, mayores
# 527   estadística, padrón, población, habitantes
# 538  demografía, padrón, habitantes, estadística
#
#     Fecha de incorporación al catálogo: Fecha de actualización:  \
# ...

# %%
census_data.to_csv('filtered_census_data.csv', index=False)

print("Filtered census data has been exported to 'filtered_census_data.csv'")
# Out:
# Filtered census data has been exported to 'filtered_census_data.csv'
